# %% [markdown]
# This notebook shows the comparison between the Cherenkov light signal generated by CORSIKA IACT and that of CHASM for the same shower. First we import a CORSIKA IACT file using the eventio python module. I wrote a wrapper here for easier access to the CORSIKA IACT data. In order to make sure you have all the correct dependencies to run this demo, I included my python conda environment in the repository under "chpy.yml."

# %%
import numpy as np
from simulation import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import eventio

# %matplotlib widget
  
corsika_file = '/home/isaac/corsika_data/unattenuated_30degree_sealevel/iact_s_000011.dat'
att_corsika_file = '/home/isaac/corsika_data/attenuated_30degree_sealevel/iact_s_000011.dat'
# corsika_file = 'IACT_shower_noatt.dat'
# att_corsika_file = 'IACT_shower_att.dat'
# corsika_file = '/home/isaac/corsika_data/correct_thinning/iact_DAT000001.dat'
# corsika_file = '/home/isaac/corsika_data/oldbuild_thinned/iact_DAT000001.dat'
corsika_file = '/home/isaac/corsika_data/old_build_diff_seed/iact_DAT000001.dat'

# for ev in eventio.IACTFile(corsika_file):
#     event = ev
# for i in range(46):
#     print(event.photon_bunches[i]['time'])
# event.photon_bunches[44]['time']
cors_no_att = EventioWrapper(corsika_file) #CORSIKA shower with no atmospheric absorbtion
cors_att = EventioWrapper(att_corsika_file) #CORSIKA shower with atmospheric absorbtion

# %% [markdown]
# Now we create a CHASM simulation, and add elements to it using the same parameters as the CORSIKA shower.

# %%
sim = ShowerSimulation()

#Add shower axis
sim.add(DownwardAxis(cors_no_att.theta, cors_no_att.phi, cors_no_att.obs))

#Add shower profile
sim.add(UserShower(cors_no_att.X, cors_no_att.nch)) #profiles could also be created using Gaisser-Hillas parameters

#Add CORSIKA IACT style spherical telescopes
sim.add(SphericalCounters(cors_no_att.counter_vectors, cors_no_att.counter_radius))

#Add wavelength interval for Cherenkov yield calculation
sim.add(Yield(cors_no_att.min_l, cors_no_att.max_l))

# %% [markdown]
# Now the simulation has all the necessary elements to calculate a Cherenkov signal.

# %%
#Create objects which calculate Cherekov signal
sim.run(mesh = True)

#Get signal photons
ng_sum = sim.get_signal_sum()

#Get attenuated signal photons
# ng_sum_att = sim.get_attenuated_signal_sum()

# %% [markdown]
# Now let's plot the Cherenkov signal from both CORSIKA IACT and CHASM.

# %%
fig = plt.figure()
plt.scatter(cors_no_att.counter_r, cors_no_att.ng_sum, c = 'k', label = 'CORSIKA IACT');
# plt.scatter(cors_no_att.counter_r, cors_att.ng_sum, c = 'g', label = 'CORSIKA IACT (Attenuated)');
plt.scatter(cors_no_att.counter_r, ng_sum, c = 'r', label = 'CHASM');
# plt.scatter(cors_no_att.counter_r, ng_sum_att, c = 'b', label = 'CHASM (Attenuated)');
plt.semilogy();
plt.legend();
plt.grid()
plt.title('Cherenkov Lateral Distribution');
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# We can also compare the arrival time distributions of CHASM photons from each stage to that of the CORSIKA IACT photon bunches. For better modeling of the leading edge of the pulse, the CHASM mesh option samples the Cherenkov distribution at rings surrounding the axis, rather than just along the axis. Charged particles are distributed to each ring according to the universal energy-independent NKG distribution.

# %%
# times, photons = sim.get_signal_times()
# sim.run(mesh = True)
# mesh_times, mesh_photons = sim.get_attenuated_signal_times()
mesh_times, mesh_photons = sim.get_signal_times()

# %% [markdown]
# Now let's look at the arrival times for various counters at various distances from the shower core.

# %%
# counters_2_plot = np.array([1,5,10,20,30,40,45]) #indices of counters for which to plot arrival time distributions
counters_2_plot = np.array([0,1,2,5,8,10,12,15,20,25,30,31,32,35,40,45])
# counters_2_plot = np.arange(0,20)
for counter in counters_2_plot:
    fig = plt.figure()
    plt.hist(cors_no_att.get_photon_times(counter), cors_no_att.iact_ghnb[counter], (cors_no_att.iact_ghmn[counter],cors_no_att.iact_ghmx[counter]),
                          color='k',
                          weights=cors_no_att.get_photons(counter),
                          histtype='step',label='CORSIKA-IACT no att')
    plt.hist(mesh_times[counter], cors_no_att.iact_ghnb[counter], (cors_no_att.iact_ghmn[counter],cors_no_att.iact_ghmx[counter]),
                      color='b',
                      weights=mesh_photons[counter],
                      histtype='step',label='CHASM no att mesh')
#     plt.hist(times[counter], cors_no_att.iact_ghnb[counter], (cors_no_att.iact_ghmn[counter],cors_no_att.iact_ghmx[counter]),
#                       color='r',
#                       weights=photons[counter],
#                       histtype='step',label='CHASM no att')
    plt.xlabel('Time (ns)')
    plt.ylabel('Number of Cherenkov photons')
    plt.title(f'Counter {cors_no_att.counter_r[counter]:.1f} m from Core.')
    plt.semilogx()
    plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# The leading edge of the Cherenkov pulse comes earlier when Cherenkov light is sampled from physical charged particle positions because those points are closer to the counters than the axis itself. Here we plot the CORSIKA IACT photon bunch source locations along with the spread axis source locations, each weighted by the number of photons produced there.

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
for s in sim.signals[:,0]:
    ng = s.calculate_ng()[0].sum(axis=0)
    ax.scatter(s.axis.vectors[:2000,0],s.axis.vectors[:2000,1],s.axis.vectors[:2000,2],c='b', s=100*ng[:2000]/ng[:2000].max(), alpha=0.2)
xb, yb, zb, pb = cors_no_att.shower_coordinates()
ax.scatter(xb,yb,zb,c='k', s=100*pb/ng[:2000].max(), alpha=0.2);
ax.scatter(cors_no_att.counter_vectors[:,0], cors_no_att.counter_vectors[:,1], cors_no_att.counter_vectors[:,2], c = 'c', s = 10);
ax.set_xlim(-8000,300);
ax.set_ylim(-300,300);
ax.set_zlim(0,5000);
ax.set_xlabel('x (m)');
ax.set_ylabel('y (m)');
ax.set_zlabel('z (m)');
zb
# Out:
# array([102548.2109375 , 101779.15625   , 101729.8125    , ...,
#         10313.2265625 ,  11256.52636719,   7527.86914062])
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(cors_no_att.X,cors_no_att.nch)
zb.min()
# Out:
# 0.02972063235938549
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cors_no_att.nch
# Out:
# array([    0., 22157., 22157., ...,  7502.,  6676.,  5384.], dtype=float32)

# %%
cors_no_att.X
# Out:
# array([0.000e+00, 1.000e+00, 2.000e+00, ..., 1.192e+03, 1.193e+03,
#        1.194e+03])

# %%
shower = sim.ingredients['shower'][0]
axis = sim.ingredients['axis'][0,0]
shower.stage(axis.X)
# Out:
# array([ 18.24295066,  17.91620389,  17.59211567,  17.27066946,
#         16.95184876,  16.63563713,  16.3220182 ,  16.01097568,
#         15.70249334,  15.39655504,  15.09314468,  14.79224627,
#         14.49384385,  14.19792156,  13.90446359,  13.61345422,
#         13.32487779,  13.03871869,  12.75496142,  12.47359052,
#         12.1945906 ,  11.91794635,  11.64364252,  11.37166394,
#         11.10199549,  10.83462214,  10.56952891,  10.30670089,
#         10.04612325,   9.78778122,   9.53166009,   9.27774523,
#          9.02602206,   8.7764761 ,   8.52909289,   8.28385808,
#          8.04075735,   7.79977648,   7.56090128,   7.32411767,
#          7.08941159,   6.85676907,   6.62617621,   6.39761915,
#          6.17108413,   5.94655743,   5.72402539,   5.50347443,
#          5.28489104,   5.06826176,   4.85357318,   4.64081199,
#          4.42996492,   4.22101877,   4.01396039,   3.80877671,
#          3.60545472,   3.40398147,   3.20434407,   3.00652969,
#          2.81052558,   2.61631902,   2.42389739,   2.23324811,
#          2.04435865,   1.85721656,   1.67180946,   1.488125  ,
#          1.30615092,   1.12587501,   0.94728511,   0.77036914,
#          0.59511506,   0.42151091,   0.24954478,   0.07920481,
#         -0.08952077,  -0.25664372,  -0.42217569,  -0.5861283 ,
#         -0.7485131 ,  -0.9093416 ,  -1.06862522,  -1.22637534,
#         -1.38260329,  -1.53732033,  -1.69053765,  -1.84226642,
#         -1.99251771,  -2.14130256,  -2.28863195,  -2.43451678,
#         -2.57896793,  -2.7219962 ,  -2.86361232,  -3.003827  ,
#         -3.14265087,  -3.28009451,  -3.41616844,  -3.55088313,
#         -3.68424898,  -3.81627637,  -3.94697557,  -4.07635686,
#         -4.2044304 ,  -4.33120635,  -4.45669478,  -4.58090571,
#         -4.70384913,  -4.82553495,  -4.94597304,  -5.06517321,
#         -5.18314521,  -5.29989875,  -5.41544349,  -5.52978901,
#         -5.64294487,  -5.75492055,  -5.8657255 ,  -5.97536911,
#         -6.0838607 ,  -6.19120957,  -6.29742494,  -6.40251599,
#         -6.50649185,  -6.6093616 ,  -6.71113425,  -6.81181879,
#         -6.91142414,  -7.00995916,  -7.10737175,  -7.20355071,
#         -7.29845009,  -7.39208689,  -7.48447793,  -7.57563977,
#         -7.66558877,  -7.75434106,  -7.84191257,  -7.928319  ,
#         -8.01357586,  -8.09769843,  -8.18070182,  -8.26260091,
#         -8.34341038,  -8.42314475,  -8.50181831,  -8.57944517,
#         -8.65603927,  -8.73161433,  -8.80618392,  -8.87976142,
#         -8.95236003,  -9.02399276,  -9.09467247,  -9.16441184,
#         -9.23322338,  -9.30111942,  -9.36811217,  -9.43421362,
#         -9.49943563,  -9.56378992,  -9.62728802,  -9.68994133,
#         -9.75176107,  -9.81275835,  -9.87294411,  -9.93232914,
#         -9.99092409, -10.04873948, -10.10578567, -10.16207291,
#        -10.21761129, -10.27241077, -10.32648118, -10.37983223,
#        -10.43247348, -10.48441437, -10.53566423, -10.58623225,
#        -10.63612749, -10.68535892, -10.73393535, -10.78186551,
#        -10.829158  , -10.87582129, -10.92186377, -10.96729368,
#        -11.01211918, -11.0563483 , -11.099989  , -11.14304908,
#        -11.18553628, -11.22745822, -11.26882242, -11.30963629,
#        -11.34990717, -11.38964227, -11.42884873, -11.46753357,
#        -11.50570374, -11.54336609, -11.58052736, -11.61719423,
#        -11.65337327, -11.68907097, -11.72429375, -11.75904791,
#        -11.79333969, -11.82717525, -11.86056064, -11.89350187,
#        -11.92600484, -11.95807538, -11.98971925, -12.02094211,
#        -12.05174958, -12.08214718, -12.11214036, -12.1417345 ,
#        -12.17093492, -12.19974684, -12.22817544, -12.25622582,
#        -12.28390301, -12.31121197, -12.33815761, -12.36474476,
#        -12.39097818, -12.41686259, -12.44240262, -12.46760287,
#        -12.49246784, -12.517002  , -12.54120975, -12.56509543,
#        -12.58866089, -12.61190592, -12.6348329 , -12.65744629,
#        -12.6797505 , -12.70174988, -12.72344872, -12.74485123,
#        -12.76596157, -12.78678385, -12.80732211, -12.82758032,
#        -12.84756242, -12.86727227, -12.88671368, -12.90589042,
#        -12.92480619, -12.94346464, -12.96186937, -12.98002392,
#        -12.99793179, -13.01559643, -13.03302124, -13.05020955,
#        -13.06716468, -13.08388987, -13.10038833, -13.11666321,
#        -13.13271764, -13.14855468, -13.16417737, -13.17958867,
#        -13.19479154, -13.20978886, -13.22458351, -13.23917828,
#        -13.25357597, -13.2677793 , -13.28179097, -13.29561365,
#        -13.30924995, -13.32270245, -13.3359737 , -13.34906622,
#        -13.36198247, -13.37472491, -13.38729592, -13.39969788,
#        -13.41193314, -13.42400399, -13.4359127 , -13.44766152,
#        -13.45925264, -13.47068826, -13.4819705 , -13.49310149,
#        -13.50408331, -13.51491802, -13.52560763, -13.53615416,
#        -13.54655957, -13.55682579, -13.56695475, -13.57694833,
#        -13.58680838, -13.59653676, -13.60613525, -13.61560565,
#        -13.62494971, -13.63416917, -13.64326573, -13.65224108,
#        -13.66109687, -13.66983475, -13.67845633, -13.6869632 ,
#        -13.69535693, -13.70363907, -13.71181113, -13.71987463,
#        -13.72783106, -13.73568186, -13.74342848, -13.75107234,
#        -13.75861485, -13.76605739, -13.77340131, -13.78064796,
#        -13.78779867, -13.79485474, -13.80181747, -13.8086881 ,
#        -13.81546791, -13.82215813, -13.82875997, -13.83527463,
#        -13.84170329, -13.84804713, -13.8543073 , -13.86048492,
#        -13.86658112, -13.872597  , -13.87853365, -13.88439214,
#        -13.89017352, -13.89587886, -13.90150916, -13.90706545,
#        -13.91254872, -13.91795996, -13.92330015, -13.92857025,
#        -13.93377119, -13.93890392, -13.94396934, -13.94896838,
#        -13.95390192, -13.95877085, -13.96357604, -13.96831834,
#        -13.9729986 , -13.97761765, -13.98217632, -13.98667542,
#        -13.99111575, -13.9954981 , -13.99982325, -14.00409196,
#        -14.00830499, -14.01246309, -14.016567  , -14.02061743,
#        -14.02461511, -14.02856075, -14.03245503, -14.03629866,
#        -14.04009229, -14.04383661, -14.04753228, -14.05117993,
#        -14.05478022, -14.05833347, -14.06183917, -14.06529712,
#        -14.06870803, -14.07207257, -14.07539144, -14.07866529,
#        -14.08189478, -14.08508056, -14.08822326, -14.09132351,
#        -14.09438192, -14.09739911, -14.10037566, -14.10331217,
#        -14.10620922, -14.10906738, -14.1118872 , -14.11466924,
#        -14.11741404, -14.12012214, -14.12279407, -14.12543035,
#        -14.12803148, -14.13059797, -14.13313032, -14.13562901,
#        -14.13809453, -14.14052735, -14.14292793, -14.14529674,
#        -14.14763422, -14.14994082, -14.15221698, -14.15446313,
#        -14.15667969, -14.1588671 , -14.16102575, -14.16315605,
#        -14.1652584 , -14.16733321, -14.16938085, -14.1714017 ,
#        -14.17339615, -14.17536457, -14.17730731, -14.17922475,
#        -14.18111723, -14.1829851 , -14.18482871, -14.1866484 ,
#        -14.1884445 , -14.19021733, -14.19196723, -14.19369451,
#        -14.19539948, -14.19708246, -14.19874374, -14.20038364,
#        -14.20200244, -14.20360044, -14.20517793, -14.20673518,
#        -14.20827249, -14.20979011, -14.21128832, -14.2127674 ,
#        -14.21422759, -14.21566917, -14.21709238, -14.21849748,
#        -14.21988472, -14.22125433, -14.22260657, -14.22394166,
#        -14.22525984, -14.22656134, -14.22784639, -14.22911521,
#        -14.23036802, -14.23160504, -14.23282649, -14.23403256,
#        -14.23522348, -14.23639944, -14.23756065, -14.2387073 ,
#        -14.2398396 , -14.24095773, -14.24206189, -14.24315227,
#        -14.24422904, -14.24529239, -14.2463425 , -14.24737955,
#        -14.24840372, -14.24941517, -14.25041407, -14.25140059,
#        -14.2523749 , -14.25333716, -14.25428753, -14.25522617,
#        -14.25615323, -14.25706886, -14.25797322, -14.25886646,
#        -14.25974872, -14.26062015, -14.2614809 , -14.26233109,
#        -14.26317088, -14.26400039, -14.26481977, -14.26562915,
#        -14.26642865, -14.26721841, -14.26799855, -14.26876921,
#        -14.2695305 , -14.27028254, -14.27102547, -14.27175939,
#        -14.27248442, -14.27320068, -14.27390829, -14.27460735,
#        -14.27529798, -14.27598029, -14.27665438, -14.27732036,
#        -14.27797833, -14.27862841, -14.27927068, -14.27990526,
#        -14.28053223, -14.28115171, -14.28176377, -14.28236853,
#        -14.28296607, -14.28355649, -14.28413988, -14.28471632,
#        -14.28528591, -14.28584873, -14.28640487, -14.28695442,
#        -14.28749746, -14.28803406, -14.28856433, -14.28908833,
#        -14.28960614, -14.29011785, -14.29062352, -14.29112324,
#        -14.29161709, -14.29210513, -14.29258744, -14.29306409,
#        -14.29353516, -14.2940007 , -14.29446081, -14.29491553,
#        -14.29536494, -14.29580911, -14.2962481 , -14.29668198,
#        -14.2971108 , -14.29753464, -14.29795356, -14.29836761,
#        -14.29877686, -14.29918137, -14.2995812 , -14.2999764 ,
#        -14.30036704, -14.30075316, -14.30113494, -14.30151259,
#        -14.30188621, -14.30225584, -14.30262154, -14.30298333,
#        -14.30334127, -14.30369539, -14.30404573, -14.30439234,
#        -14.30473525, -14.30507451, -14.30541014, -14.3057422 ,
#        -14.30607072, -14.30639573, -14.30671728, -14.30703539,
#        -14.30735012, -14.30766149, -14.30796954, -14.3082743 ,
#        -14.30857582, -14.30887411, -14.30916923, -14.3094612 ,
#        -14.30975006, -14.31003583, -14.31031856, -14.31059828,
#        -14.31087501, -14.31114879, -14.31141965, -14.31168762,
#        -14.31195273, -14.31221502, -14.31247451, -14.31273123,
#        -14.31298522, -14.3132365 , -14.31348509, -14.31373104,
#        -14.31397436, -14.31421509, -14.31445325, -14.31468887,
#        -14.31492198, -14.31515266, -14.31538103, -14.31560717,
#        -14.31583108, -14.31605279, -14.31627233, -14.3164897 ,
#        -14.31670493, -14.31691804, -14.31712905, -14.31733797,
#        -14.31754483, -14.31774964, -14.31795242, -14.3181532 ,
#        -14.31835198, -14.31854878, -14.31874364, -14.31893655,
#        -14.31912754, -14.31931663, -14.31950383, -14.31968917,
#        -14.31987265, -14.3200543 , -14.32023413, -14.32041216,
#        -14.3205884 , -14.32076287, -14.3209356 , -14.32110658,
#        -14.32127585, -14.32144341, -14.32160928, -14.32177347,
#        -14.32193601, -14.32209691, -14.32225617, -14.32241383,
#        -14.32256988, -14.32272436, -14.32287726, -14.32302861,
#        -14.32317842, -14.32332671, -14.32347349, -14.32361876,
#        -14.32376256, -14.32390488, -14.32404575, -14.32418518,
#        -14.32432317, -14.32445976, -14.32459494, -14.32472873,
#        -14.32486114, -14.3249922 , -14.3251219 , -14.32525026,
#        -14.3253773 , -14.32550303, -14.32562745, -14.32575059,
#        -14.32587245, -14.32599305, -14.3261124 , -14.32623051,
#        -14.32634738, -14.32646305, -14.3265775 , -14.32669077,
#        -14.32680285, -14.32691376, -14.32702351, -14.32713211,
#        -14.32723957, -14.32734591, -14.32745113, -14.32755524,
#        -14.32765826, -14.3277602 , -14.32786106, -14.32796086,
#        -14.3280596 , -14.3281573 , -14.32825397, -14.32834961,
#        -14.32844424, -14.32853787, -14.3286305 , -14.32872215,
#        -14.32881282, -14.32890253, -14.32899128, -14.32907909,
#        -14.32916596, -14.3292519 , -14.32933692, -14.32942103,
#        -14.32950424, -14.32958655, -14.32966798, -14.32974854,
#        -14.32982823, -14.32990706, -14.32998504, -14.33006219,
#        -14.33013849, -14.33021397, -14.33028864, -14.3303625 ,
#        -14.33043555, -14.33050782, -14.33057929, -14.33064999,
#        -14.33071993, -14.3307891 , -14.33085751, -14.33092518,
#        -14.33099211, -14.3310583 , -14.33112378, -14.33118853,
#        -14.33125257, -14.33131592, -14.33137856, -14.33144052,
#        -14.33150179, -14.33156239, -14.33162231, -14.33168158,
#        -14.33174019, -14.33179816, -14.33185548, -14.33191216,
#        -14.33196822, -14.33202365, -14.33207847, -14.33213268,
#        -14.33218628, -14.33223928, -14.33229169, -14.33234352,
#        -14.33239477, -14.33244544, -14.33249554, -14.33254509,
#        -14.33259407, -14.33264251, -14.3326904 , -14.33273775,
#        -14.33278456, -14.33283085, -14.33287661, -14.33292186,
#        -14.3329666 , -14.33301082, -14.33305455, -14.33309778,
#        -14.33314051, -14.33318276, -14.33322453, -14.33326582,
#        -14.33330665, -14.333347  , -14.33338689, -14.33342633,
#        -14.33346531, -14.33350385, -14.33354194, -14.3335796 ,
#        -14.33361682, -14.33365362, -14.33368999, -14.33372594,
#        -14.33376147, -14.33379659, -14.33383131, -14.33386562,
#        -14.33389954, -14.33393306, -14.33396619, -14.33399893,
#        -14.3340313 , -14.33406328, -14.3340949 , -14.33412614,
#        -14.33415702, -14.33418753, -14.33421769, -14.33424749,
#        -14.33427695, -14.33430605, -14.33433482, -14.33436324,
#        -14.33439133, -14.33441909, -14.33444652, -14.33447362,
#        -14.33450041, -14.33452687, -14.33455302, -14.33457886,
#        -14.3346044 , -14.33462963, -14.33465455, -14.33467918,
#        -14.33470352, -14.33472756, -14.33475132, -14.33477479,
#        -14.33479798, -14.33482089, -14.33484353, -14.33486589,
#        -14.33488798, -14.33490981, -14.33493137, -14.33495268,
#        -14.33497372, -14.33499451, -14.33501505, -14.33503533,
#        -14.33505537, -14.33507517, -14.33509473, -14.33511404,
#        -14.33513312, -14.33515197, -14.33517059, -14.33518898,
#        -14.33520714, -14.33522508, -14.3352428 , -14.3352603 ,
#        -14.33527759, -14.33529466, -14.33531151, -14.33532815,
#        -14.33534458, -14.3353608 , -14.33537681, -14.33539262,
#        -14.33540823, -14.33542364, -14.33543886, -14.33545388,
#        -14.33546871, -14.33548335, -14.3354978 , -14.33551207,
#        -14.33552616, -14.33554006, -14.33555379, -14.33556734,
#        -14.33558072, -14.33559392, -14.33560696, -14.33561982,
#        -14.33563253, -14.33564506, -14.33565744, -14.33566966,
#        -14.33568172, -14.33569362, -14.33570537, -14.33571696,
#        -14.33572841, -14.33573971, -14.33575086, -14.33576186,
#        -14.33577273, -14.33578345, -14.33579403, -14.33580447,
#        -14.33581478, -14.33582495, -14.33583499, -14.3358449 ,
#        -14.33585468, -14.33586433, -14.33587386, -14.33588326,
#        -14.33589253, -14.33590169, -14.33591072, -14.33591963,
#        -14.33592843, -14.33593711, -14.33594568, -14.33595413,
#        -14.33596247, -14.33597071, -14.33597883, -14.33598684,
#        -14.33599475, -14.33600256, -14.33601025, -14.33601785,
#        -14.33602535, -14.33603275, -14.33604004, -14.33604724,
#        -14.33605435, -14.33606136, -14.33606827, -14.3360751 ,
#        -14.33608183, -14.33608847, -14.33609502, -14.33610149,
#        -14.33610787, -14.33611416, -14.33612036, -14.33612649,
#        -14.33613253, -14.33613849, -14.33614437, -14.33615017,
#        -14.33615589, -14.33616153, -14.3361671 , -14.33617259,
#        -14.33617801, -14.33618335, -14.33618862, -14.33619382,
#        -14.33619895, -14.33620401, -14.33620899, -14.33621392,
#        -14.33621877, -14.33622356, -14.33622828, -14.33623294,
#        -14.33623753, -14.33624206, -14.33624653, -14.33625093,
#        -14.33625528, -14.33625957, -14.33626379, -14.33626796,
#        -14.33627207, -14.33627613, -14.33628012, -14.33628407,
#        -14.33628796, -14.33629179, -14.33629557, -14.3362993 ,
#        -14.33630298, -14.3363066 , -14.33631018, -14.3363137 ,
#        -14.33631718, -14.3363206 , -14.33632398, -14.33632732,
#        -14.3363306 , -14.33633384, -14.33633704, -14.33634018,
#        -14.33634329, -14.33634635, -14.33634937, -14.33635234,
#        -14.33635528, -14.33635817, -14.33636102, -14.33636383,
#        -14.33636661, -14.33636934, -14.33637203, -14.33637469,
#        -14.3363773 , -14.33637988, -14.33638243, -14.33638493,
#        -14.33638741, -14.33638984, -14.33639224, -14.33639461,
#        -14.33639695, -14.33639925, -14.33640151, -14.33640375,
#        -14.33640595, -14.33640812, -14.33641026, -14.33641237,
#        -14.33641445, -14.3364165 , -14.33641852, -14.33642051,
#        -14.33642247, -14.3364244 , -14.3364263 , -14.33642818])
